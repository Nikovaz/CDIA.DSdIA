# %% [markdown]
# # TP01 - Deepnote Galarza Nicolas
#
# ### Datos del Estudiante:
# **Nombre y Apellido:** Nicolás Galarza Vázquez
# **Carrera:** Tecnicatura Superior en Ciencia de Datos e Inteligencia Artificial (IFTS Nº 24)
# **Materia:** Desarrollo de Sistemas de Inteligencia Artificial (DSIA)
# **Docente:** Prof. Valeria Feito
# **Año:** 2026 - 2º Cuatrimestre

# %% [markdown]
# ### ¿Quién sos?
# Soy Nicolás Galarza Vázquez, estudiante de la Tecnicatura Superior en Ciencia de Datos e IA y apasionado por la automatización y la arquitectura de sistemas inteligentes.
#
# ### ¿Qué hacés?
# Me dedico al desarrollo de software y a la construcción de soluciones de automatización con inteligencia artificial aplicadas a procesos comerciales y de negocio.
#
# ### ¿Qué expectativas tenés de la materia?
# Espero aprender a utilizar herramientas avanzadas de programación, modelado de Machine Learning y visión/lenguaje para el análisis de datos masivos y la toma de decisiones basada en datos.

# %%
print("Mi primer notebook en Deepnote")

print('Quien sos?')
print('Soy Nicolas Galarza Vazquez')
print('¿Que haces?')
print('Estoy aprendiendo a usar Deepnote')
print('¿Que expectativas tenes de la materia?')
print('Espero aprender a usar herramientas de programacion para el analisis y modelado de datos')
# Out:
# Mi primer notebook en Deepnote
# Quien sos?
# Soy Nicolas Galarza Vazquez
# Que haces?
# Estoy aprendiendo a usar Deepnote
# Que expectativas tenes de la materia?
# Espero aprender a usar herramientas de programacion para el analisis y modelado de datos
