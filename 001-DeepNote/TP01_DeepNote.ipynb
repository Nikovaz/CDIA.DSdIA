# %%
print ('Quien sos?') 
print ('Soy Nicolas Galarza Vazquez')
print ('¿Que haces?')
print ('Estoy aprendiendo a usar Deepnote')
print ('¿Que expectativas tenes de la materia?')
print ('Espero aprender a usar herramientas de programacion para el analisis de datos ya que hago trabajos de automatizaciones \npero quiero darles a los clientes analicis de sus datos como la cantidad de gente que compra tales productos y darle un top 10.\n Lo hago a esa clase de trabajo pero me gustaria aprender hacerlos sin IA y potenciar desde otros angulos la fluctuacion de los datos')
# Out:
# Quien sos?
# Soy Nicolas Galarza Vazquez
# ¿Que haces?
# Estoy aprendiendo a usar Deepnote
# ¿Que expectativas tenes de la materia?
# Espero aprender a usar herramientas de programacion para el analisis de datos ya que hago trabajos de automatizaciones
# pero quiero darles a los clientes analicis de sus datos como la cantidad de gente que compra tales productos y darle un top 10.
#  Lo hago a esa clase de trabajo pero me gustaria aprender hacerlos sin IA y potenciar desde otros angulos la fluctuacion de los datos

# %% [markdown]
# ### Quien sos?
# Soy Nicolas Galarza Vazquez
# ¿Que haces?
# Estoy aprendiendo a usar Deepnote
# ¿Que expectativas tenes de la materia?
# Espero aprender a usar herramientas de programacion para el analisis de datos ya que hago trabajos de automatizaciones
# pero quiero darles a los clientes analicis de sus datos como la cantidad de gente que compra tales productos y darle un top 10\.
#  Lo hago a esa clase de trabajo pero me gustaria aprender hacerlos sin IA y potenciar desde otros angulos la fluctuacion de los datos

# %% [markdown]
# <img src="GL81185-5.jpeg" width="" align="" />

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=4d0941fd-cc8c-4fb8-8690-c7ca8f3796a2' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' />
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
