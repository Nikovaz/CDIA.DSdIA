# %% [markdown]
# # 📁 Trabajo Práctico Integrador (TPI) - TPI_2entrega
# **Materia:** Desarrollo de Sistemas de Inteligencia Artificial (DSIA)
# **Institución:** IFTS Nº 24 - Tecnicatura Superior en Ciencia de Datos e Inteligencia Artificial
# **Docente:** Prof. Valeria Feito
# **Estudiante:** Galarza, Nicolás
# **Repositorio:** [CDIA.DSdIA](https://github.com/Nikovaz/CDIA.DSdIA)
#
# ---
#
# ### 📌 Estado: Instancia Reservada para Cursada
# Este notebook contiene la estructura base para la instancia **TPI_2entrega** según el cronograma de evaluación de DSIA.

# %%
# Espacio de trabajo para el desarrollo del TPI
print("🚀 Módulo TPI inicializado para entrega.")
